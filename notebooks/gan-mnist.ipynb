# %%
import tensorflow as tf
import numpy as np
import sys
sys.path.append('../../generative-adversarial-nets/')
from ganetwork import GAN
from sklearn import datasets
from sklearn.datasets import fetch_mldata
from sklearn.preprocessing import minmax_scale, LabelBinarizer

# %%
mnist = fetch_mldata('MNIST original', data_home=".")
X = minmax_scale(mnist.data.astype(np.float32))

# %%
discriminator_layers=[(X.shape[1], None), (128, tf.nn.relu), (1, None)]
generator_layers=[(100, None), (128, tf.nn.relu), (X.shape[1], None)]
gan = GAN(discriminator_layers, generator_layers)

# %%
gan.train(X, nb_epoch=2000, batch_size=64)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

m = 100
n = 100
matrix = np.random.normal(0,1,size=(m, n))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

#fig.show()
#fig.canvas.draw()

for i in range(0,100):
    ax.clear()
    ax.plot(matrix[i,:])
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib
